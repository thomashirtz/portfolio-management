# %%
import sys
from pathlib import Path
portfolio_management_path = Path.cwd().parent
sys.path.insert(0, str(portfolio_management_path))

from portfolio_management.database.retrieve import get_dataset

# %%
dataset = get_dataset('database_1')
dataset
# Out:
# <xarray.Dataset>
# Dimensions:     (index: 104872, property: 9, symbol: 4)
# Coordinates:
#   * symbol      (symbol) <U7 'BTCTUSD' 'ETHTUSD' 'BNBTUSD' 'XRPTUSD'
#   * property    (property) <U28 'open' 'high' ... 'taker_buy_quote_asset_volume'
#   * index       (index) int32 0 1 2 3 4 5 ... 104867 104868 104869 104870 104871
# Data variables:
#     data        (symbol, index, property) float32 7.165e+03 7.165e+03 ... 0.0
#     close_time  (symbol, index) datetime64[ns] 2020-01-01 ... 2020-12-31
#     open_time   (symbol, index) datetime64[ns] 2020-01-01T00:05:00 ... 2020-1...
# Attributes:
#     interval:  5m
