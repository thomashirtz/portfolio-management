# %%
from binance import Client

# %%
client = Client()
tickers = client.get_all_tickers()
tickers
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.06090500'},
#  {'symbol': 'LTCBTC', 'price': '0.00405900'},
#  {'symbol': 'BNBBTC', 'price': '0.00951700'},
#  {'symbol': 'NEOBTC', 'price': '0.00101700'},
#  {'symbol': 'QTUMETH', 'price': '0.00316900'},
#  {'symbol': 'EOSETH', 'price': '0.00197100'},
#  {'symbol': 'SNTETH', 'price': '0.00003270'},
#  {'symbol': 'BNTETH', 'price': '0.00153600'},
#  {'symbol': 'BCCBTC', 'price': '0.07908100'},
#  {'symbol': 'GASBTC', 'price': '0.00021990'},
#  {'symbol': 'BNBETH', 'price': '0.15620000'},
#  {'symbol': 'BTCUSDT', 'price': '32734.95000000'},
#  {'symbol': 'ETHUSDT', 'price': '1993.65000000'},
#  {'symbol': 'HSRBTC', 'price': '0.00041400'},
#  {'symbol': 'OAXETH', 'price': '0.00017780'},
#  {'symbol': 'DNTETH', 'price': '0.00002801'},
#  {'symbol': 'MCOETH', 'price': '0.00577200'},
#  {'symbol': 'ICNETH', 'price': '0.00166300'},
#  {'symbol': 'MCOBTC', 'price': '0.00021140'},
#  {'symbol': 'WTCBTC', 'price': '0.00001590'},
# ...

# %%
symbols = [t['symbol'] for t in tickers if t['symbol'].endswith('TUSD')]
symbols
# Out:
# ['BTCTUSD',
#  'ETHTUSD',
#  'BNBTUSD',
#  'XRPTUSD',
#  'EOSTUSD',
#  'XLMTUSD',
#  'ADATUSD',
#  'TRXTUSD',
#  'NEOTUSD',
#  'PAXTUSD',
#  'USDCTUSD',
#  'LINKTUSD',
#  'WAVESTUSD',
#  'BCHABCTUSD',
#  'BCHSVTUSD',
#  'LTCTUSD',
#  'USDSTUSD',
#  'BTTTUSD',
#  'ZECTUSD',
#  'ATOMTUSD',
#  'ETCTUSD',
#  'BATTUSD',
#  'PHBTUSD',
#  'TFUELTUSD',
#  'ONETUSD',
#  'FTMTUSD',
#  'BCPTTUSD',
#  'ALGOTUSD',
#  'GTOTUSD',
#  'ANKRTUSD',
#  'TUSDBTUSD',
#  'BCHTUSD']

# %%
for ticker in tickers:
    if ticker['symbol'] in symbols:
        print(ticker)
# Out:
# {'symbol': 'BTCTUSD', 'price': '32725.45000000'}
# {'symbol': 'ETHTUSD', 'price': '2003.34000000'}
# {'symbol': 'BNBTUSD', 'price': '312.50000000'}
# {'symbol': 'XRPTUSD', 'price': '0.62410000'}
# {'symbol': 'EOSTUSD', 'price': '3.91570000'}
# {'symbol': 'XLMTUSD', 'price': '0.06833000'}
# {'symbol': 'ADATUSD', 'price': '1.28940000'}
# {'symbol': 'TRXTUSD', 'price': '0.05996000'}
# {'symbol': 'NEOTUSD', 'price': '11.81800000'}
# {'symbol': 'PAXTUSD', 'price': '0.99950000'}
# {'symbol': 'USDCTUSD', 'price': '1.00000000'}
# {'symbol': 'LINKTUSD', 'price': '17.35400000'}
# {'symbol': 'WAVESTUSD', 'price': '1.07200000'}
# {'symbol': 'BCHABCTUSD', 'price': '220.20000000'}
# {'symbol': 'BCHSVTUSD', 'price': '59.17000000'}
# {'symbol': 'LTCTUSD', 'price': '133.56000000'}
# {'symbol': 'USDSTUSD', 'price': '1.00000000'}
# {'symbol': 'BTTTUSD', 'price': '0.00241940'}
# {'symbol': 'ZECTUSD', 'price': '51.48000000'}
# {'symbol': 'ATOMTUSD', 'price': '2.59800000'}
# ...
